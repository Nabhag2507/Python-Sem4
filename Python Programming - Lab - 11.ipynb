# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 11</b></center>
# <center><b><h3>Roll No : 465</b></center>
# <center><b><h3>Name : Sorathiya Nabhag</b></center>
# <pre>

# %% [markdown]
# # Progrmas based on Python Data Structure + UDF + File Handling

# %% [markdown]
# ### Practical 1: Count Lines, Words and Characters
#
# **Problem Definition:**
# Write a Python program to read text from a file and count the total number of lines, words, and characters. The result should be written to an output file.

# %%
with open('demo.txt') as df:
    print(f"Total Characters: {len(df.read())}")
    df.seek(0, 0)
    print(f"Total words: {len(df.read().split())}")
    df.seek(0, 0)
    print(f"Total Lines: {len(df.readlines())}")
# Out:
# Total Characters: 268
# Total words: 51
# Total Lines: 11

# %% [markdown]
# ### Practical 2: Search a Word in a File
#
# **Problem Definition:**
# Write a Python program to search a given word in a text file and count its occurrences. Store the result in an output file.

# %%
word = input("Enter word to find occurrence :")
with open('demo.txt') as df:
    with open('output.txt', 'w') as out:
        out.write(f"Word {word} occurred {df.read().lower().split().count(word.lower())} times")
# Out:
# Enter word to find occurrence :hello

# %% [markdown]
# ### Practical 3: Student Marks and Average
#
# **Problem Definition:**
# Write a Python program to read roll number, name, and marks of students from a file. Store marks in a list, calculate the average using a user-defined function, and write student details along with average marks to an output file.

# %%
with open('student.txt') as df:
    arr = df.read().split()
    stuNames = []
    stuAvgMarks = []
    for i in range(0,len(arr),3):
        stuNames.append(arr[i])
        
    for i in range(2,len(arr),3):
        stuAvgMarks.append(sum(list(map(int,arr[i].split(',')))) / 5)
        
    with open('output.txt', 'w') as out:
        for i in range(len(stuNames)):
            out.write(f"{stuNames[i]} : {stuAvgMarks[i]}\n")

# %% [markdown]
# ### Practical 4: Maximum and Minimum using Tuple
#
# **Problem Definition:**
# Write a Python program to read numbers from a file, store them in a tuple, and find the maximum and minimum values. Write the result to an output file.

# %%
with open('numbers.txt') as df:
    tup = tuple(map(int,df.read().split(',')))
    print(tup)
    with open ('output.txt', 'w') as out:
        out.write(f"Max : {max(tup)}\nMin : {min(tup)}")
# Out:
# (1, 2, 3, 5, 1, 5, 52, 12, 6, 2, 854, 1, 18, 1, 851, 81, 81, 841, 54, 84, 65, 16)

# %% [markdown]
# ### Practical 5: Remove Duplicate Words using Set
#
# **Problem Definition:**
# Write a Python program to read words from a file and remove duplicate words using a set. Store the unique words in an output file.

# %%
with open('demo.txt', 'r+') as df:
    ans = df.read().split()
    print(ans)
    
    ans = set(ans)

    with open('output.txt', 'w') as df:
        df.write(str(ans))
# Out:
# ['first', 'Hello', 'wo', 'second', 'This', 'is', 'from', 'demo', 'file.', 'third', 'Hello', 'fourth', 'This', 'is', 'from', 'demo', 'file.', 'fifth', 'Hello', 'wo', 'sixth', 'This', 'is', 'from', 'demo', 'file.first', 'Hello', 'wo', 'second', 'This', 'is', 'from', 'demo', 'file.', 'third', 'Hello', 'fourth', 'This', 'is', 'from', 'demo', 'file.', 'fifth', 'Hello', 'wo', 'sixth', 'This', 'is', 'from', 'demo', 'file.']

# %% [markdown]
# ### Practical 6: Word Frequency using Dictionary
#
# **Problem Definition:**
# Write a Python program to count the frequency of each word in a text file using a dictionary and write the result to an output file.

# %%
with open('demo.txt') as df:
    d = {}
    l = df.read().split()
    for i in l:
        d[i] = l.count(i)

        with open('output.txt', 'w') as out:
            out.write(str(d))

# %% [markdown]
# ### Practical 7: Student Result and Grade Calculation
#
# **Problem Definition:**
# Write a Python program to read roll number, name, and marks of students from a file. Use a user-defined function to determine grade (A/B/C/Fail) and write the student result to an output file.
#
# **Grade Criteria:**
# - Marks ≥ 75 : Grade A
# - Marks ≥ 60 : Grade B
# - Marks ≥ 40 : Grade C
# - Marks < 40 : Fail

# %%
with open('student.txt') as df:
    arr = df.read().split()
    stuNames = []
    stuGrades = []
    for i in range(0,len(arr),3):
        stuNames.append(arr[i])
        
    for i in range(2,len(arr),3):
        avg = sum(list(map(int,arr[i].split(',')))) / 5
        if avg >= 75 :stuGrades.append('Grade A')
        elif avg >= 65 :stuGrades.append('Grade B')
        elif avg >= 40 :stuGrades.append('Grade C')
        else :stuGrades.append('Fail')
        
        
    with open('output.txt', 'w') as out:
        for i in range(len(stuNames)):
            out.write(f"{stuNames[i]} : {stuGrades[i]}\n")
