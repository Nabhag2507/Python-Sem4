# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 12</b></center>
# <center><b><h3>Roll No : 465</b></center>
# <center><b><h3>Name : Sorathiya Nabhag</b></center>
# <pre>

# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### 01) WAP to handle following exceptions:
# 1. ZeroDivisionError
# 2. ValueError
# 3. TypeError
# #### Note: handle them using separate except blocks and also using single except block too.

# %%
try:
    print(10 / 2)
    print(2 + 5)
    print(int("hello"))
except Exception as err:
    print(type(err))
# Out:
# 5.0
# 7
# <class 'ValueError'>

# %% [markdown]
# ### 02)  WAP to handle following exceptions:
# 1. IndexError
# 2. KeyError

# %%
try:
    arr = [1, 2, 3]
    print(arr[5])
except Exception as err:
    print(type(err))
    
try:
    d = {1: "a", 2: "b"}
    print(d[5])
except Exception as err:
    print(type(err))
# Out:
# <class 'IndexError'>
# <class 'KeyError'>

# %% [markdown]
# ### 03) WAP to handle following exceptions:
# 1. FileNotFoundError
# 2. ModuleNotFoundError

# %%
try:
    with open("filenotfound.txt" "r") as df:
        print(df.read())
    
except Exception as err:
    print(type(err))
    
try:
    import abcd
    
except Exception as err:
    print(type(err))
# Out:
# <class 'FileNotFoundError'>
# <class 'ModuleNotFoundError'>

# %% [markdown]
# ### 04) WAP that handles all type of exceptions in a single except block in standard error message format.

# %%
try:
    print(10 / 0)
except Exception as err:
    print(f"some error occured: {err}")
# Out:
# some error occured: division by zero

# %% [markdown]
# ### 05) WAP to demonstrate else  and finally block.

# %%
try:
    print(10 / 5)
except Exception as err:
    print(err)
else:
    print("No error occured")
finally:
    print("End of programme")
# Out:
# 2.0
# No error occured
# End of programme

# %% [markdown]
# ### 06) WAP to create an udf divide(a,b) that handles ZeroDivisionError.

# %%
def divide(a, b):
    try:
        print(a / b)
    except:
        print("Can not divide by zero")
divide(5, 0)
# Out:
# Can not divide by zero

# %% [markdown]
# ### 07) WAP to accept item prices and calculate total. Raise ValueError if price is negative, otherwise print the total bill amount.

# %%
def total(l):
    ans = 0
    for i in l:
        try:
            if i < 0:
                raise ValueError("price value cannot be negative")
        except ValueError as err:
            print(err)
            return -1
        else:
            ans += i
    return ans

print(total([10, 20, 30])) 
print(total([10, -5, 30]))
# Out:
# 60
# price value cannot be negative
# -1

# %% [markdown]
# ### 08) Create a short program that prompts the user for a list of grades separated by commas.
# #### Split the string into individual grades and use a list comprehension to convert each string to an integer.
# #### You should use a try statement to inform the user when the values they entered cannot be converted.

# %%
user_input = input("Please enter your grades, separated by commas: ")
grade_strings = user_input.split(",")

try:
    grades = [int(grade.strip()) for grade in grade_strings]
    
    print("Converted grades:", grades)

except ValueError:
    print("The grades you entered were in an invalid format. Please ensure they are only numbers.")
# Out:
# Please enter your grades, separated by commas: a,d,d,e,a
# The grades you entered were in an invalid format. Please ensure they are only numbers.

# %% [markdown]
# ### 09) Accept 5 subject marks (0-100). Use assert for validation.
#
# #### Sample Input (Error Case)
# #####  Enter marks: 110
#
# #### Sample Output (Error Case)
# ##### AssertionError: Marks should be between 0 and 100.
#
# #### Sample Input (Normal Case)
# ##### Valid marks entered
#
# #### Sample Output (Normal Case)
# ##### Average Marks displayed

# %%
try:
    m1 = int(input("Enter marks of sub 1 :"))
    m2 = int(input("Enter marks of sub 2 :"))
    m3 = int(input("Enter marks of sub 3 :"))
    m4 = int(input("Enter marks of sub 4 :"))
    m5 = int(input("Enter marks of sub 5 :"))
    
    if (m1 > 100 or m1 < 0 or
        m2 > 100 or m2 < 0 or
        m3 > 100 or m3 < 0 or
        m4 > 100 or m4 < 0 or
        m5 > 100 or m5 < 0):
        raise Exception("Marks should be between 0 and 100")
except Exception as err:
    print(err)
else:
    print("Valid marks entered :)")
    print((m1 + m2 + m3 + m4 + m5) / 5)
# Out:
# Enter marks of sub 1 :50
# Enter marks of sub 2 :56
# Enter marks of sub 3 :56
# Enter marks of sub 4 :84
# Enter marks of sub 5 :94
# Valid marks entered :)
# 68.0

# %% [markdown]
# ### 10) WAP that gets password from user. Password must have at least 8 characters and one digit.
# ### Raise WeakPasswordError if invalid, print the messsage "Correct" otherwise.

# %%
class WeakPasswordError(Exception):
    pass

try:
    password = input("Enter your password: ")
    has_digit = any(char.isdigit() for char in password)
    
    if len(password) < 8 or not has_digit:
        raise WeakPasswordError("Weak password error")
except WeakPasswordError as err:
    print(err)
else:
    print("Correct :)")
# Out:
# Enter your password: adadsfasdf5
# Correct :)

# %% [markdown]
# ### 11) WAP to raise your custom Exception named NegativeNumberError with the error message : "Cannot calculate the square root of a negative number" :
# #### if the given number is negative.
# #### otherwise print the square root of the given number.

# %%
import math

class NegativeNumberError(Exception):
    pass

try:
    num = int(input("Enter any number :"))
    if num < 0:
        raise NegativeNumberError("Number cannot be less than zero")
        
    else:
        print(math.sqrt(num))
except Exception as err:
    print(err)
# Out:
# Enter any number :-9
# Number cannot be less than zero
