# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 13</b></center>
# <center><b><h3>Roll No.: 465</b></center>
# <center><b><h3>Name: Sorathiya Nabhag S.</b></center>
# <pre>

# %% [markdown]
# ### 01) WAP to create Calculator module which defines functions like add, sub,mul and div.
# ### Create another .py file that uses the functions available in Calculator module.

# %%
import calculator

# %%
calculator.calculator(5, 10, '*')
# Out:
# 50

# %% [markdown]
# ### 02) WAP to pick a random character from a given String.

# %%
import random
s = "VishalTargeriyan"
random.choice(s)
# Out:
# 'h'

# %% [markdown]
# ### 03) WAP to pick a random element from a given list.

# %%
li = list(range(1, 21))
random.choice(li)
# Out:
# 11

# %% [markdown]
# ### 04) WAP to roll a dice in such a way that every time you get the same number.

# %%
random.seed(42)
random.randint(1, 7)
# Out:
# 6

# %% [markdown]
# ### 05) WAP to generate 3 random integers between 100 and 999 which is divisible by 5.

# %%
li = [random.randrange(100, 1000, 5) for _ in range(3)]
li
# Out:
# [375, 395, 745]

# %% [markdown]
# ### 06) WAP to generate 100 random lottery tickets and pick two lucky tickets from it and announce them as Winner and Runner up respectively.

# %%
li = [random.randrange(1, 1001) for _ in range(100)]
random.choices(li, k = 2)

print(f"First winner is {li[0]}")
print(f"First runner up is {li[1]}")
# Out:
# First winner is 736
# First runner up is 714

# %% [markdown]
# ### 07) WAP to print current date and time in Python.

# %%
import datetime

print(datetime.date.today())
print(datetime.datetime.now())
# Out:
# 2026-03-11
# 2026-03-11 10:23:24.875476

# %% [markdown]
# ### 08) Subtract a week (7 days) from a given date in Python.

# %%
date_str = input("Enter date (YYYY-MM-DD): ")

day = datetime.datetime.strptime(date_str, "%Y-%m-%d").date()

day - datetime.timedelta(days = 7)
# Out:
# Enter date (YYYY-MM-DD):  2007-07-25
# datetime.date(2007, 7, 18)

# %% [markdown]
# ### 09) WAP to Calculate number of days between two given dates.

# %%
date1 = input("Enter date (YYYY-MM-DD): ")
date1 = datetime.datetime.strptime(date1, "%Y-%m-%d").date()

date2 = input("Enter date (YYYY-MM-DD): ")
date2 = datetime.datetime.strptime(date2, "%Y-%m-%d").date()

print(date2 - date1)
# Out:
# Enter date (YYYY-MM-DD):  1000-01-01
# Enter date (YYYY-MM-DD):  1000-05-05
# 124 days, 0:00:00

# %% [markdown]
# ### 10) WAP to Find the day of the week of a given date.(i.e. wether it is sunday/monday/tuesday/etc.)

# %%
date_str = input("Enter date (YYYY-MM-DD): ")
date = datetime.datetime.strptime(date_str, "%Y-%m-%d")

day = date.strftime("%A")

print("Day of the week is:", day)
# Out:
# Enter date (YYYY-MM-DD):  2007-07-25
# Day of the week is: Wednesday
