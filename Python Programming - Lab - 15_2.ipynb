# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h2>Python Programming - 2301CS404</b></center>
# <center><b><h2>Lab - 15 (2) </b></center>
# <center><b><h3>Roll No.: 465</b></center>
# <center><b><h3>Name: Sorathiya Nabhag S.</b></center>
# <pre>

# %% [markdown]
# ## Continued..

# %% [markdown]
# ### 10) Calculate area of a ractangle using object as an argument to a method.

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

class GeometryTools:
    def get_area(self, rect_obj):
        return rect_obj.length * rect_obj.width

my_rectangle = Rectangle(10, 5)

tools = GeometryTools()
result = tools.get_area(my_rectangle)

print(f"The area of the rectangle is: {result}")
# Out:
# The area of the rectangle is: 50

# %% [markdown]
# ### 11) Calculate the area of a square.
# ### Include a Constructor, a method to calculate area named area() and a method named output() that prints the output and is invoked by area().

# %%
class square:
    def __init__(self, length):
        self.length = length
        
    def output(self, result):
        print(result)
        
    def area(self):
        return self.output(self.length * self.length)
    
s = square(2)
s.area()
# Out:
# 4

# %% [markdown]
# ### 12) Calculate the area of a rectangle.
# ### Include a Constructor, a method to calculate area named area() and a method named output() that prints the output and is invoked by area().
# ### Also define a class method that compares the two sides of reactangle. An object is instantiated only if the two sides are different; otherwise a message should be displayed : THIS IS SQUARE.

# %%
class Rectangle:
    def __init__(self, l, w):
        self.l, self.w = l, w

    @classmethod
    def check_and_create(cls, l, w):
        if l == w:
            print("THIS IS SQUARE")
            return None
        return cls(l, w)

    def area(self):
        res = self.l * self.w
        self.output(res)

    def output(self, res):
        print(f"Area: {res}")

rect = Rectangle.check_and_create(10, 10)
if rect: rect.area()
# Out:
# THIS IS SQUARE

# %% [markdown]
# ### 13) Define a class Square having a private attribute "side".
# ### Implement get_side and set_side methods to accees the private attribute from outside of the class.

# %%
class Square:
    def __init__(self, side):
        self.__side = side 
    def get_side(self):
        return self.__side

    def set_side(self, value):
        if value > 0:
            self.__side = value
        else:
            print("Side must be positive!")

my_square = Square(10)

print(f"Current side: {my_square.get_side()}") 

my_square.set_side(15)
print(f"Updated side: {my_square.get_side()}")
# Out:
# Current side: 10
# Updated side: 15

# %% [markdown]
# ### 14) Create a class Profit that has a method named getProfit that accepts profit from the user.
# ### Create a class Loss that has a method named getLoss that accepts loss from the user.
# ### Create a class BalanceSheet that inherits from both classes Profit and Loss and calculates the balanace. It has two methods getBalance() and printBalance().

# %%
class profit:
    def __init__(self):
        self.profit = 0
        
    def getProfit(self):
        self.profit = float(input("Enter profit: "))
             
class loss:
    def __init__(self):
        self.loss = 0

    def getLoss(self):
        self.loss = float(input("Enter loss: "))
        
class balanceSheet(profit, loss):
    def __init__(self):
        profit.__init__(self)
        loss.__init__(self)
        self.balance = 0
        
    def getBalance(self):
        self.balance = self.profit - self.loss
        return self.balance
    
    def printBalance(self):
        print(f"""
        Profit: {self.profit}
        Loss: {self.loss}
        Balance: {self.balance}
        """)
        
account = balanceSheet()
account.getProfit()
account.getLoss()
account.getBalance()
account.printBalance()
# Out:
# Enter profit: 50000
# Enter loss: 12000
#
#         Profit: 50000.0
#         Loss: 12000.0
#         Balance: 38000.0

# %% [markdown]
# ### 15) WAP to demonstrate all types of inheritance.

# %%
# 1. Single
class A:
    def show(self): print("A")
class B(A):
    pass
B().show()

# 2. Multiple
class X:
    def x(self): print("X")
class Y:
    def y(self): print("Y")
class Z(X, Y):
    pass
z = Z()
z.x()
z.y()

# 3. Multilevel
class P:
    def p(self): print("P")
class Q(P):
    pass
class R(Q):
    pass
R().p()

# 4. Hierarchical
class Parent:
    def show(self): print("Parent")
class C1(Parent): pass
class C2(Parent): pass
C1().show()
C2().show()

# 5. Hybrid
class A:
    def a(self): print("A")
class B(A): pass
class C(A): pass
class D(B, C): pass
D().a()
# Out:
# A
# X
# Y
# P
# Parent
# Parent
# A

# %% [markdown]
# ### 16) Create a Person class with a constructor that takes two arguments name and age.
# ### Create a child class Employee that inherits from Person and adds a new attribute salary.
# ### Override the __init__ method in Employee to call the parent class's __init__ method using the super() and then initialize the salary attribute.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
class Employee(Person):
    def __init__(self, name, age, salary):
        super().__init__(name, age)
        self.salary = salary
        
p = Employee("Nabhag", 18, 300000)
p.name, p.age, p.salary
# Out:
# ('Nabhag', 18, 300000)

# %% [markdown]
# ### 17) Create a Shape class with a draw method that is not implemented.
# ### Create three child classes Rectangle, Circle, and Triangle that implement the draw method with their respective drawing behaviors.
# ### Create a list of Shape objects that includes one instance of each child class, and then iterate through the list and call the draw method on each object.

# %%
class Shape:
    def draw(self):
        pass
    
class Rectangle(Shape):
    def draw(self):
        print("Drawing Rectangle")
        
class Circle(Shape):
    def draw(self):
        print("Drawing Circle")
        
class Triangle(Shape):
    def draw(self):
        print("Drawing Triangle")
        
li = [Rectangle(), Circle(), Triangle()]

for l in li:
    l.draw()
# Out:
# Drawing Rectangle
# Drawing Circle
# Drawing Triangle
